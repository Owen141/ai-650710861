# %% [markdown]
# - นำเข้าlibrary pandas สำหรับจัดตารางข้อมูล(DataFrame)

# %%
import pandas as pd

# %% [markdown]
# - อ่านไฟล์ CSV แล้วเก็บข้อมูลตัวแปร df_master

# %%
df_master = pd.read_csv("student.csv")

# %% [markdown]
# - ตรวจสอบดูว่า ข้อมูลมีกี่แถว กับ กี่คอลัมส์

# %%
df_master.shape
# Out:
# (20, 10)

# %% [markdown]
# - แสดงข้อมูลคร่าวๆของ df_master

# %%
df_master.head()
# Out:
#    รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0         64001     สมชาย  20.0   ชาย     วิทยาศาสตร์  3.21       170.0
# 1         64002    สมหญิง  21.0  หญิง           วิทย์  3.45       165.0
# 2         64003       NaN   NaN  Male         Science  3.67       175.0
# 3         64004  สมศักดิ์  22.0     ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4         64005      สมใจ  19.0     ญ           วิศวะ  3.89       160.0
#
#    น้ำหนัก_kg  ชั่วโมงเรียน_ต่อสัปดาห์ วันที่ลงทะเบียน
# 0        65.0                     15.0      2024-01-23
# 1        58.0                     20.0      2024-02-05
# 2         NaN                     25.0      2024-01-13
# 3        70.0                     10.0      2023-12-30
# 4        52.0                     30.0      2024-01-27

# %% [markdown]
# - แสดงข้อมูลทั้งหมดของ df_master

# %%
df_master
# Out:
#     รหัสนักศึกษา      ชื่อ   อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย   20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง   21.0    หญิง           วิทย์  3.45       165.0
# 2          64003       NaN    NaN    Male         Science  3.67       175.0
# 3          64004  สมศักดิ์   22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ   19.0       ญ           วิศวะ  3.89       160.0
# 5          64006     กานต์  150.0     ชาย     Engineering  3.12       172.0
# 6          64007     กิตติ   21.0    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา   20.0       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป   23.0       M            Arts  3.34       163.0
# 9          64010      ดารา   21.0    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ    NaN     NaN             NaN  3.78         NaN
# ...

# %% [markdown]
# # การจัดการข้อมูลหาย
# **วิธีที่ 1** ลบแถวที่มีค่าหาย
# - สร้างข้อมูลตัวอย่าง 10 คน โดยมี 1 คนที่ไม่กรอกข้อมูล

# %%
data = {
    'ชื่อ': ['ก้อง', 'กล้า', 'กิ่ง', 'กานต์', 'กุล', 'กบ', 'กิตติ', 'กมล', 'กร', 'กนก'],
    'อายุ': [21, 22, 20, 21, None, 22, 21, 20, 21, 22],  # เฉพาะกุลไม่กรอกอายุ
    'GPA': [3.5, 3.2, 3.8, 3.0, 3.7, 3.3, 3.6, 3.4, 3.1, 3.9]
}

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (10, 3)

# %%
df.head()
# Out:
#     ชื่อ  อายุ  GPA
# 0   ก้อง  21.0  3.5
# 1   กล้า  22.0  3.2
# 2   กิ่ง  20.0  3.8
# 3  กานต์  21.0  3.0
# 4    กุล   NaN  3.7

# %% [markdown]
# - ลบแถวทั้งหมดที่มีค่า NaN(ค่าหาย) ออกจาก DataFrameจะลบทั้งแถวถ้าคอลัมน์ใดคอลัมน์หนึ่งมี NaN

# %%
df_clean = df.dropna()

# %% [markdown]
# - เก็บ DataFrame ใหม่ที่ลบค่าหายออกแล้ว (ไม่แก้ไข df เดิม)

# %%
df_clean
# Out:
#     ชื่อ  อายุ  GPA
# 0   ก้อง  21.0  3.5
# 1   กล้า  22.0  3.2
# 2   กิ่ง  20.0  3.8
# 3  กานต์  21.0  3.0
# 5     กบ  22.0  3.3
# 6  กิตติ  21.0  3.6
# 7    กมล  20.0  3.4
# 8     กร  21.0  3.1
# 9    กนก  22.0  3.9

# %% [markdown]
# **วิธีที่ 2** เติมค่าด้วยค่าเฉลี่ย
# - สร้างข้อมูลตัวอย่าง 5 คน โดยคนที่ 2 (สมหญิง) ไม่ได้กรอกอายุ (None)

# %%
data = {
    'ชื่อ': ['สมชาย', 'สมหญิง', 'สมศักดิ์', 'สมใจ', 'สมปอง'],
    'อายุ': [20, None, 19, 22, 21]  # สมหญิงไม่ได้กรอกอายุ
}
df = pd.DataFrame(data)

# %% [markdown]
# - แสดงข้อมูลตัวอย่างโค้ดด้านบนทั้งหมด

# %%
df.head()
# Out:
#        ชื่อ  อายุ
# 0     สมชาย  20.0
# 1    สมหญิง   NaN
# 2  สมศักดิ์  19.0
# 3      สมใจ  22.0
# 4     สมปอง  21.0

# %% [markdown]
# - คำนวณค่าเฉลี่ยของคอลัมน์ 'อายุ' โดยไม่นับรวมค่า NaN

# %%
mean_age = df['อายุ'].mean()

# %% [markdown]
# - แสดงข้อมูลค่าเฉลี่ยของคอลัมน์ 'อายุ'

# %%
mean_age
# Out:
# np.float64(20.5)

# %%
df
# Out:
#        ชื่อ  อายุ
# 0     สมชาย  20.0
# 1    สมหญิง  20.5
# 2  สมศักดิ์  19.0
# 3      สมใจ  22.0
# 4     สมปอง  21.0

# %% [markdown]
# **วิธีที่ 3** เติมค่าด้วยค่าที่พบบ่อยที่สุด
#
# - สร้างข้อมูลตัวอย่าง 5 คน โดยคนที่ 3 (สมศักดิ์) ไม่ได้กรอกคณะ (None)

# %%
data = {
    'ชื่อ': ['สมชาย', 'สมหญิง', 'สมศักดิ์', 'สมใจ', 'สมปอง'],
    'คณะ': ['วิทยาศาสตร์', 'วิทยาศาสตร์', None, 'ศิลปศาสตร์', 'วิทย์']
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#        ชื่อ          คณะ
# 0     สมชาย  วิทยาศาสตร์
# 1    สมหญิง  วิทยาศาสตร์
# 2  สมศักดิ์         None
# 3      สมใจ   ศิลปศาสตร์
# 4     สมปอง        วิทย์

# %% [markdown]
# - แสดง dataframe

# %%
df
# Out:
#          ชื่อ  อายุ
# 0   นักศึกษา1    20
# 1   นักศึกษา2    21
# 2   นักศึกษา3    22
# 3   นักศึกษา4    19
# 4   นักศึกษา5    20
# 5   นักศึกษา6   150
# 6   นักศึกษา7    21
# 7   นักศึกษา8    22
# 8   นักศึกษา9    23
# 9  นักศึกษา10    18

# %% [markdown]
# # การทำให้ข้อมูลเป็นมาตรฐาน
#
# - สร้างฟังก์ชันที่รับชื่อคณะเข้ามาแล้วแปลงเป็นชื่อมาตรฐาน
# - ส่วน if-else เป็น การตรวจสอบว่าชื่อที่รับเข้ามาอยู่ใน list ของชื่อที่เป็นไปได้หรือไม่
# - การ return คือ คืนค่าข้อมูลของชื่อคณะที่เป็นมาตรฐาน

# %%
def standardize_faculty(name):
    if name in ['วิทยาศาสตร์', 'วิทย์', 'Science', 'คณะวิทยาศาสตร์']:
        return 'วิทยาศาสตร์'
    elif name in ['ศิลปศาสตร์', 'ศิลป์', 'Arts']:
        return 'ศิลปศาสตร์'
    else:
        return name

# %% [markdown]
# - ใช้ฟังก์ชันกับทุกค่าในคอลัมน์ 'คณะ' ซึ่ง apply จะเรียกฟังก์ชันทีละแถวและส่งค่าในแถวนั้นเข้าไปในฟังก์ชัน

# %%
df['คณะ_มาตรฐาน'] = df['คณะ'].apply(standardize_faculty)

# %% [markdown]
# - สร้างคอลัมน์ใหม่ที่เก็บชื่อคณะที่เป็นมาตรฐานแล้ว

# %%
df['คณะ_มาตรฐาน']
# Out:
# 0    วิทยาศาสตร์
# 1    วิทยาศาสตร์
# 2    วิทยาศาสตร์
# 3     ศิลปศาสตร์
# 4    วิทยาศาสตร์
# Name: คณะ_มาตรฐาน, dtype: object

# %% [markdown]
# # การจัดการค่าผิดปกติ
# - ตัวอย่างของค่าผิดปกติเหมือนคนที่อ้างว่าวิ่ง 100 เมตรได้ใน 2 วินาที
# - quantile(0.25) - หาค่า Quartile ที่ 1 (Q1) คือค่าที่มี 25% ของข้อมูลน้อยกว่าหรือเท่ากับค่านี้
# - quantile(0.75) - หาค่า Quartile ที่ 3 (Q3) คือค่าที่มี 75% ของข้อมูลน้อยกว่าหรือเท่ากับค่านี้
# - IQR = Q3 - Q1 - Interquartile Range คือช่วงระหว่าง Q1 และ Q3 บอกถึงการกระจายตัวของข้อมูลส่วนกลาง 50%
# - 1.5 * IQR - ตัวเลข 1.5 เป็นค่ามาตรฐานที่นิยมใช้ในการหาค่าผิดปกติ

# %%
# สร้างข้อมูลตัวอย่าง
data = {
    'ชื่อ': ['นักศึกษา1', 'นักศึกษา2', 'นักศึกษา3', 'นักศึกษา4', 'นักศึกษา5',
             'นักศึกษา6', 'นักศึกษา7', 'นักศึกษา8', 'นักศึกษา9', 'นักศึกษา10'],
    'อายุ': [20, 21, 22, 19, 20, 150, 21, 22, 23, 18]  # 150 คือค่าผิดปกติ
}
df = pd.DataFrame(data)

print("ข้อมูลต้นฉบับ")
print(df)
print(f"\nค่าเฉลี่ยอายุ (รวมค่าผิดปกติ) - {df['อายุ'].mean():.2f}")

# วิธีง่ายๆ - ใช้ IQR (Interquartile Range)
Q1 = df['อายุ'].quantile(0.25)
Q3 = df['อายุ'].quantile(0.75)
IQR = Q3 - Q1

# กำหนดขอบเขต
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# Out:
# ข้อมูลต้นฉบับ
#          ชื่อ  อายุ
# 0   นักศึกษา1    20
# 1   นักศึกษา2    21
# 2   นักศึกษา3    22
# 3   นักศึกษา4    19
# 4   นักศึกษา5    20
# 5   นักศึกษา6   150
# 6   นักศึกษา7    21
# 7   นักศึกษา8    22
# 8   นักศึกษา9    23
# 9  นักศึกษา10    18
#
# ค่าเฉลี่ยอายุ (รวมค่าผิดปกติ) - 33.60

# %%
df = pd.DataFrame(data)

# %% [markdown]
# - พิมพ์ค่าขอบเขตล่าง และ บน

# %%
print(lower_bound)
print(upper_bound)
# Out:
# 17.0
# 25.0

# %% [markdown]
# - กรองเฉพาะแถวที่มีอายุอยู่ในช่วงที่กำหนด

# %%
df_no_outliers = df[(df['อายุ'] >= lower_bound) & (df['อายุ'] <= upper_bound)]

# %% [markdown]
# - แสดง dataframe ของ อายุนศ.แต่ละคนที่มีอายุอยู่ในช่วงที่กำหนด

# %%
df_no_outliers
# Out:
#          ชื่อ  อายุ
# 0   นักศึกษา1    20
# 1   นักศึกษา2    21
# 2   นักศึกษา3    22
# 3   นักศึกษา4    19
# 4   นักศึกษา5    20
# 6   นักศึกษา7    21
# 7   นักศึกษา8    22
# 8   นักศึกษา9    23
# 9  นักศึกษา10    18

# %% [markdown]
# - dataframe ของ ขอบเขตล่างสำหรับตัดสินว่าค่าใดเป็นค่าผิดปกติ

# %%
df['อายุ'] >= lower_bound
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: อายุ, dtype: bool

# %% [markdown]
# - dataframe ของ ขอบเขตบนสำหรับตัดสินว่าค่าใดเป็นค่าผิดปกติ

# %%
df['อายุ'] <= upper_bound
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8     True
# 9     True
# Name: อายุ, dtype: bool

# %% [markdown]
# # One-Hot Encoding แปลงข้อมูลประเภทเป็นตัวเลข
#  - สร้าง DataFrame ตัวอย่างที่มีข้อมูลประเภท (คณะ) ที่ต้องการแปลง

# %%
data = pd.DataFrame({
    'ชื่อ': ['A', 'B', 'C', 'D'],
    'คณะ': ['วิทย์', 'ศิลป์', 'วิทย์', 'วิศวะ']
})

# %% [markdown]
# - แปลงคอลัมน์ 'คณะ' เป็นรูปแบบ One-Hot Encoding

# %%
data_encoded = pd.get_dummies(data, columns=['คณะ'])
print(data_encoded)
# Out:
#   ชื่อ  คณะ_วิทย์  คณะ_วิศวะ  คณะ_ศิลป์
# 0    A       True      False      False
# 1    B      False      False       True
# 2    C       True      False      False
# 3    D      False       True      False

# %% [markdown]
# # การรวม Features
# -สร้างข้อมูลตัวอย่างส่วนสูง และ น้ำหนัก ของ นศ.แต่ละคน

# %%
student_health = pd.DataFrame({
    'ชื่อ': ['สมชาย', 'สมหญิง', 'สมศักดิ์'],
    'ส่วนสูง_cm': [170, 165, 175],
    'น้ำหนัก_kg': [65, 55, 80]
})

# %%
student_health['BMI'] = student_health['น้ำหนัก_kg'] / (student_health['ส่วนสูง_cm']/100)**2
student_health['สุขภาพ'] = pd.cut(student_health['BMI'],
                                   bins=[0, 18.5, 25, 30, 100],
                                   labels=['ผอม', 'ปกติ', 'อ้วน', 'อ้วนมาก'])

# %%
student_health
# Out:
#        ชื่อ  ส่วนสูง_cm  น้ำหนัก_kg        BMI สุขภาพ
# 0     สมชาย         170          65  22.491349   ปกติ
# 1    สมหญิง         165          55  20.202020   ปกติ
# 2  สมศักดิ์         175          80  26.122449   อ้วน

# %% [markdown]
# - พิมพ์ข้อมูลชื่อ, ค่าBMI และ อาการสุขภาพ

# %%
print(student_health[['ชื่อ', 'BMI', 'สุขภาพ']])
# Out:
#        ชื่อ        BMI สุขภาพ
# 0     สมชาย  22.491349   ปกติ
# 1    สมหญิง  20.202020   ปกติ
# 2  สมศักดิ์  26.122449   อ้วน

# %% [markdown]
# # Dataset ข้อมูลนักศึกษาลงทะเบียนกิจกรรม
# - สร้าง dictionary ที่เก็บข้อมูลดิบ โดยมีปัญหาตามจริงที่พบในงาน

# %%
raw_data = {
    'รหัสนักศึกษา': ['64001', '64002', '64003', '64004', '64005'],
    'ชื่อ': ['สมชาย', 'สมหญิง', None, 'สมศักดิ์', 'สมใจ'],
    'คณะ': ['วิทย์', 'ศิลปศาสตร์', 'วิทยาศาสตร์', 'Arts', 'วิศวะ'],
    'ชั้นปี': [2, 3, 2, None, 4],
    'GPA': [3.2, 3.8, -1, 2.9, 4.5],  # -1 และ 4.5 ผิดปกติ
    'กิจกรรม': ['กีฬา', 'ดนตรี', 'กีฬา,ดนตรี', None, 'อาสา'],
    'เวลาเข้าร่วม': ['08:00', '9.30', '08:30', '08:00', None]
}
df_student = pd.DataFrame(raw_data)

# %% [markdown]
# - สร้าง dictionary สำหรับแปลงชื่อคณะ

# %%
faculty_mapping = {
    'วิทย์': 'วิทยาศาสตร์',
    'วิทยาศาสตร์': 'วิทยาศาสตร์',
    'ศิลปศาสตร์': 'ศิลปศาสตร์',
    'Arts': 'ศิลปศาสตร์',
    'วิศวะ': 'วิศวกรรมศาสตร์'
}

# %%
faculty_mapping
# Out:
# {'วิทย์': 'วิทยาศาสตร์',
#  'วิทยาศาสตร์': 'วิทยาศาสตร์',
#  'ศิลปศาสตร์': 'ศิลปศาสตร์',
#  'Arts': 'ศิลปศาสตร์',
#  'วิศวะ': 'วิศวกรรมศาสตร์'}

# %%
df_student['คณะ'] = df_student['คณะ'].map(faculty_mapping)

# %% [markdown]
# - แสดง dataframe ของข้อมูลนศ.ที่เข้าร่วมกิจกรรม

# %%
df_student
# Out:
#   รหัสนักศึกษา      ชื่อ             คณะ  ชั้นปี  GPA     กิจกรรม เวลาเข้าร่วม
# 0        64001     สมชาย     วิทยาศาสตร์     2.0  3.2        กีฬา        08:00
# 1        64002    สมหญิง      ศิลปศาสตร์     3.0  3.8       ดนตรี         9.30
# 2        64003      None     วิทยาศาสตร์     2.0 -1.0  กีฬา,ดนตรี        08:30
# 3        64004  สมศักดิ์      ศิลปศาสตร์     NaN  2.9        None        08:00
# 4        64005      สมใจ  วิศวกรรมศาสตร์     4.0  4.5        อาสา         None
